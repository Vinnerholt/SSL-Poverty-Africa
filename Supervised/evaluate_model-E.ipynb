# %%
import torch
import pandas as pd
import numpy as np
import pickle as pkl

# %%
import supervised_dataset
import importlib
importlib.reload(supervised_dataset)
# Out:
# <module 'supervised_dataset' from '/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/Supervised/supervised_dataset.py'>

# %%
import sys
sys.path.insert(0, '/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/geography-aware-ssl/moco_fmow/moco')
from ms_nl_resnet import MS_NL_ResNet18
# Out:
# /cephyr/users/benvin/Alvis/.local/lib/python3.8/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension: /cephyr/users/benvin/Alvis/.local/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZNK3c106IValue23reportToTensorTypeErrorEv
#   warn(f"Failed to load image Python extension: {e}")

# %%
fold = 'E'
gpu = 3

losses = pd.read_csv('moco_pretrained/fold_{}/losses_fold_{}_epoch_0020_.txt'.format(fold, fold), sep=",", header=None)
best_epoch = losses[1].argmin()
print("Best epoch: ", best_epoch)
print("Best epoch val_loss: ", losses[1].iloc[best_epoch])

model = MS_NL_ResNet18(num_classes=1)
#optimizer = torch.optim.Adam(model.parameters(), lr=0.02)

## Supervised
checkpoint_path = 'moco_pretrained/fold_{}/checkpoint_fold_{}_{:04d}.pth.tar'.format(fold, fold, best_epoch)
print("Model loaded: ", checkpoint_path)
checkpoint = torch.load(checkpoint_path, map_location='cpu')

checkpoint_dict = dict()
for key in checkpoint['state_dict'].keys():
    resnet_key=key.replace("module.", "")
    checkpoint_dict[resnet_key]=checkpoint['state_dict'][key]

model.load_state_dict(checkpoint_dict)

loc = 'cuda:{}'.format(gpu)
checkpoint = torch.load('moco_pretrained/fold_{}/checkpoint_fold_{}_{:04d}.pth.tar'.format(fold, fold, best_epoch), map_location=loc)



#optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# Out:
# Best epoch:  20
# Best epoch val_loss:  148.55619378523394
# Model loaded:  moco_pretrained/fold_E/checkpoint_fold_E_0020.pth.tar

# %%
torch.cuda.set_device(gpu)
model.cuda(gpu)
print()

criterion = torch.nn.MSELoss().cuda(gpu)

# %%
csv = "/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/Supervised/dhs_clusters_paths.csv"
folds_path = '/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/CreateFolds/new_dhs_incountry_folds.pkl'


with open(folds_path, 'rb') as handle:
        folds = pkl.load(handle)
        
test_dataset = supervised_dataset.SupervisedDataset(csv, csv_indices=folds[fold]['test'])

batch_size = 64
test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# TEST MODEL
iwi_pred = []
iwi_true = []

model.eval()
for i, (images, labels) in enumerate(test_loader):
    #print(images.size())
    images = images.cuda(gpu)
    labels = labels.cuda(gpu)
    
    preds = model(images)
    preds = torch.squeeze(preds)
    #print(preds.size())
    
    loss = criterion(preds, labels)
    print(loss)
    
    for pred in preds:
        iwi_pred.append(pred.item())
    
    for label in labels:
        iwi_true.append(label.item())
    
    
    #iwi_preds.extend(preds.numpy())
    
    #print("batch: ", i)
    print(i, "/", len(test_loader))
    print()
# Out:
# tensor(218.2181, device='cuda:3', grad_fn=<MseLossBackward>)
# 0 / 178
#
# tensor(206.1114, device='cuda:3', grad_fn=<MseLossBackward>)
# 1 / 178
#
# tensor(189.4746, device='cuda:3', grad_fn=<MseLossBackward>)
# 2 / 178
#
# tensor(70.4518, device='cuda:3', grad_fn=<MseLossBackward>)
# 3 / 178
#
# tensor(80.5024, device='cuda:3', grad_fn=<MseLossBackward>)
# 4 / 178
#
# tensor(79.2403, device='cuda:3', grad_fn=<MseLossBackward>)
# 5 / 178
#
# tensor(55.7888, device='cuda:3', grad_fn=<MseLossBackward>)
# 6 / 178
#
# tensor(61.6947, device='cuda:3', grad_fn=<MseLossBackward>)
# 7 / 178
#
# tensor(46.7962, device='cuda:3', grad_fn=<MseLossBackward>)
# 8 / 178
#
# tensor(85.7434, device='cuda:3', grad_fn=<MseLossBackward>)
# 9 / 178
#
# tensor(45.1917, device='cuda:3', grad_fn=<MseLossBackward>)
# 10 / 178
#
# tensor(181.6221, device='cuda:3', grad_fn=<MseLossBackward>)
# 11 / 178
#
# tensor(179.9998, device='cuda:3', grad_fn=<MseLossBackward>)
# 12 / 178
#
# tensor(169.1958, device='cuda:3', grad_fn=<MseLossBackward>)
# 13 / 178
#
# tensor(48.2980, device='cuda:3', grad_fn=<MseLossBackward>)
# 14 / 178
#
# tensor(197.7357, device='cuda:3', grad_fn=<MseLossBackward>)
# 15 / 178
#
# tensor(179.8040, device='cuda:3', grad_fn=<MseLossBackward>)
# 16 / 178
#
# tensor(77.2493, device='cuda:3', grad_fn=<MseLossBackward>)
# 17 / 178
#
# tensor(109.3111, device='cuda:3', grad_fn=<MseLossBackward>)
# 18 / 178
#
# tensor(117.6048, device='cuda:3', grad_fn=<MseLossBackward>)
# 19 / 178
#
# tensor(171.5600, device='cuda:3', grad_fn=<MseLossBackward>)
# 20 / 178
#
# tensor(626.4026, device='cuda:3', grad_fn=<MseLossBackward>)
# 21 / 178
#
# tensor(325.8837, device='cuda:3', grad_fn=<MseLossBackward>)
# 22 / 178
#
# tensor(454.0237, device='cuda:3', grad_fn=<MseLossBackward>)
# 23 / 178
#
# tensor(434.6363, device='cuda:3', grad_fn=<MseLossBackward>)
# 24 / 178
#
# tensor(356.2142, device='cuda:3', grad_fn=<MseLossBackward>)
# 25 / 178
#
# tensor(171.6258, device='cuda:3', grad_fn=<MseLossBackward>)
# 26 / 178
#
# tensor(119.8483, device='cuda:3', grad_fn=<MseLossBackward>)
# 27 / 178
#
# tensor(128.5009, device='cuda:3', grad_fn=<MseLossBackward>)
# 28 / 178
#
# tensor(230.6609, device='cuda:3', grad_fn=<MseLossBackward>)
# 29 / 178
#
# tensor(350.1152, device='cuda:3', grad_fn=<MseLossBackward>)
# 30 / 178
#
# tensor(384.1997, device='cuda:3', grad_fn=<MseLossBackward>)
# 31 / 178
#
# tensor(302.8969, device='cuda:3', grad_fn=<MseLossBackward>)
# 32 / 178
#
# tensor(329.5331, device='cuda:3', grad_fn=<MseLossBackward>)
# 33 / 178
#
# tensor(324.4786, device='cuda:3', grad_fn=<MseLossBackward>)
# 34 / 178
#
# tensor(362.5986, device='cuda:3', grad_fn=<MseLossBackward>)
# 35 / 178
#
# tensor(358.4772, device='cuda:3', grad_fn=<MseLossBackward>)
# 36 / 178
#
# tensor(315.4307, device='cuda:3', grad_fn=<MseLossBackward>)
# 37 / 178
#
# tensor(166.3231, device='cuda:3', grad_fn=<MseLossBackward>)
# 38 / 178
#
# tensor(163.1272, device='cuda:3', grad_fn=<MseLossBackward>)
# 39 / 178
#
# tensor(136.2365, device='cuda:3', grad_fn=<MseLossBackward>)
# 40 / 178
#
# tensor(145.7438, device='cuda:3', grad_fn=<MseLossBackward>)
# 41 / 178
#
# tensor(110.9507, device='cuda:3', grad_fn=<MseLossBackward>)
# 42 / 178
#
# tensor(270.0627, device='cuda:3', grad_fn=<MseLossBackward>)
# 43 / 178
#
# tensor(64.2743, device='cuda:3', grad_fn=<MseLossBackward>)
# 44 / 178
#
# tensor(63.7779, device='cuda:3', grad_fn=<MseLossBackward>)
# 45 / 178
#
# tensor(58.9063, device='cuda:3', grad_fn=<MseLossBackward>)
# 46 / 178
#
# tensor(69.0077, device='cuda:3', grad_fn=<MseLossBackward>)
# 47 / 178
#
# tensor(144.6018, device='cuda:3', grad_fn=<MseLossBackward>)
# 48 / 178
#
# tensor(162.4136, device='cuda:3', grad_fn=<MseLossBackward>)
# 49 / 178
#
# tensor(210.8275, device='cuda:3', grad_fn=<MseLossBackward>)
# 50 / 178
#
# tensor(165.3969, device='cuda:3', grad_fn=<MseLossBackward>)
# 51 / 178
#
# tensor(153.0210, device='cuda:3', grad_fn=<MseLossBackward>)
# 52 / 178
#
# tensor(112.8179, device='cuda:3', grad_fn=<MseLossBackward>)
# 53 / 178
#
# tensor(114.2375, device='cuda:3', grad_fn=<MseLossBackward>)
# 54 / 178
#
# tensor(311.4377, device='cuda:3', grad_fn=<MseLossBackward>)
# 55 / 178
#
# tensor(254.1051, device='cuda:3', grad_fn=<MseLossBackward>)
# 56 / 178
#
# tensor(95.0273, device='cuda:3', grad_fn=<MseLossBackward>)
# 57 / 178
#
# tensor(91.2395, device='cuda:3', grad_fn=<MseLossBackward>)
# 58 / 178
#
# tensor(128.7629, device='cuda:3', grad_fn=<MseLossBackward>)
# 59 / 178
#
# tensor(162.9724, device='cuda:3', grad_fn=<MseLossBackward>)
# 60 / 178
#
# tensor(143.3874, device='cuda:3', grad_fn=<MseLossBackward>)
# 61 / 178
#
# tensor(54.1657, device='cuda:3', grad_fn=<MseLossBackward>)
# 62 / 178
#
# tensor(75.8140, device='cuda:3', grad_fn=<MseLossBackward>)
# 63 / 178
#
# tensor(56.1422, device='cuda:3', grad_fn=<MseLossBackward>)
# 64 / 178
#
# tensor(229.3068, device='cuda:3', grad_fn=<MseLossBackward>)
# 65 / 178
#
# tensor(267.6236, device='cuda:3', grad_fn=<MseLossBackward>)
# 66 / 178
#
# tensor(155.2533, device='cuda:3', grad_fn=<MseLossBackward>)
# 67 / 178
#
# tensor(93.4697, device='cuda:3', grad_fn=<MseLossBackward>)
# 68 / 178
#
# tensor(178.3161, device='cuda:3', grad_fn=<MseLossBackward>)
# 69 / 178
#
# tensor(143.0338, device='cuda:3', grad_fn=<MseLossBackward>)
# 70 / 178
#
# tensor(131.5426, device='cuda:3', grad_fn=<MseLossBackward>)
# 71 / 178
#
# tensor(121.1413, device='cuda:3', grad_fn=<MseLossBackward>)
# 72 / 178
#
# tensor(115.6492, device='cuda:3', grad_fn=<MseLossBackward>)
# 73 / 178
#
# tensor(222.6137, device='cuda:3', grad_fn=<MseLossBackward>)
# 74 / 178
#
# tensor(228.5312, device='cuda:3', grad_fn=<MseLossBackward>)
# 75 / 178
#
# tensor(60.0821, device='cuda:3', grad_fn=<MseLossBackward>)
# 76 / 178
#
# tensor(72.4537, device='cuda:3', grad_fn=<MseLossBackward>)
# 77 / 178
#
# tensor(49.6330, device='cuda:3', grad_fn=<MseLossBackward>)
# 78 / 178
#
# tensor(48.9268, device='cuda:3', grad_fn=<MseLossBackward>)
# 79 / 178
#
# tensor(65.1357, device='cuda:3', grad_fn=<MseLossBackward>)
# 80 / 178
#
# tensor(57.3715, device='cuda:3', grad_fn=<MseLossBackward>)
# 81 / 178
#
# tensor(40.9345, device='cuda:3', grad_fn=<MseLossBackward>)
# 82 / 178
#
# tensor(43.4179, device='cuda:3', grad_fn=<MseLossBackward>)
# 83 / 178
#
# tensor(63.4114, device='cuda:3', grad_fn=<MseLossBackward>)
# 84 / 178
#
# tensor(79.8032, device='cuda:3', grad_fn=<MseLossBackward>)
# 85 / 178
#
# tensor(73.4710, device='cuda:3', grad_fn=<MseLossBackward>)
# 86 / 178
#
# tensor(63.2812, device='cuda:3', grad_fn=<MseLossBackward>)
# 87 / 178
#
# tensor(53.2700, device='cuda:3', grad_fn=<MseLossBackward>)
# 88 / 178
#
# tensor(29.6555, device='cuda:3', grad_fn=<MseLossBackward>)
# 89 / 178
#
# tensor(19.1024, device='cuda:3', grad_fn=<MseLossBackward>)
# 90 / 178
#
# tensor(56.8147, device='cuda:3', grad_fn=<MseLossBackward>)
# 91 / 178
#
# tensor(88.9300, device='cuda:3', grad_fn=<MseLossBackward>)
# 92 / 178
#
# tensor(75.9905, device='cuda:3', grad_fn=<MseLossBackward>)
# 93 / 178
#
# tensor(136.6052, device='cuda:3', grad_fn=<MseLossBackward>)
# 94 / 178
#
# tensor(194.6273, device='cuda:3', grad_fn=<MseLossBackward>)
# 95 / 178
#
# tensor(62.7561, device='cuda:3', grad_fn=<MseLossBackward>)
# 96 / 178
#
# tensor(97.8718, device='cuda:3', grad_fn=<MseLossBackward>)
# 97 / 178
#
# tensor(74.4715, device='cuda:3', grad_fn=<MseLossBackward>)
# 98 / 178
#
# tensor(62.1525, device='cuda:3', grad_fn=<MseLossBackward>)
# 99 / 178
#
# tensor(42.4186, device='cuda:3', grad_fn=<MseLossBackward>)
# 100 / 178
#
# tensor(44.6447, device='cuda:3', grad_fn=<MseLossBackward>)
# 101 / 178
#
# tensor(55.0347, device='cuda:3', grad_fn=<MseLossBackward>)
# 102 / 178
#
# tensor(56.5557, device='cuda:3', grad_fn=<MseLossBackward>)
# 103 / 178
#
# tensor(47.9628, device='cuda:3', grad_fn=<MseLossBackward>)
# 104 / 178
#
# tensor(46.2926, device='cuda:3', grad_fn=<MseLossBackward>)
# 105 / 178
#
# tensor(53.5938, device='cuda:3', grad_fn=<MseLossBackward>)
# 106 / 178
#
# tensor(87.6084, device='cuda:3', grad_fn=<MseLossBackward>)
# 107 / 178
#
# tensor(38.6835, device='cuda:3', grad_fn=<MseLossBackward>)
# 108 / 178
#
# tensor(137.8176, device='cuda:3', grad_fn=<MseLossBackward>)
# 109 / 178
#
# tensor(131.2859, device='cuda:3', grad_fn=<MseLossBackward>)
# 110 / 178
#
# tensor(52.1933, device='cuda:3', grad_fn=<MseLossBackward>)
# 111 / 178
#
# tensor(101.5744, device='cuda:3', grad_fn=<MseLossBackward>)
# 112 / 178
#
# tensor(717.1105, device='cuda:3', grad_fn=<MseLossBackward>)
# 113 / 178
#
# tensor(372.4640, device='cuda:3', grad_fn=<MseLossBackward>)
# 114 / 178
#
# tensor(128.8215, device='cuda:3', grad_fn=<MseLossBackward>)
# 115 / 178
#
# tensor(105.7127, device='cuda:3', grad_fn=<MseLossBackward>)
# 116 / 178
#
# tensor(281.7113, device='cuda:3', grad_fn=<MseLossBackward>)
# 117 / 178
#
# tensor(355.2006, device='cuda:3', grad_fn=<MseLossBackward>)
# 118 / 178
#
# tensor(245.2275, device='cuda:3', grad_fn=<MseLossBackward>)
# 119 / 178
#
# tensor(177.0016, device='cuda:3', grad_fn=<MseLossBackward>)
# 120 / 178
#
# tensor(130.1691, device='cuda:3', grad_fn=<MseLossBackward>)
# 121 / 178
#
# tensor(229.1264, device='cuda:3', grad_fn=<MseLossBackward>)
# 122 / 178
#
# tensor(174.5591, device='cuda:3', grad_fn=<MseLossBackward>)
# 123 / 178
#
# tensor(318.1549, device='cuda:3', grad_fn=<MseLossBackward>)
# 124 / 178
#
# tensor(136.8526, device='cuda:3', grad_fn=<MseLossBackward>)
# 125 / 178
#
# tensor(132.1917, device='cuda:3', grad_fn=<MseLossBackward>)
# 126 / 178
#
# tensor(422.2953, device='cuda:3', grad_fn=<MseLossBackward>)
# 127 / 178
#
# tensor(389.4499, device='cuda:3', grad_fn=<MseLossBackward>)
# 128 / 178
#
# tensor(240.6573, device='cuda:3', grad_fn=<MseLossBackward>)
# 129 / 178
#
# tensor(884.2382, device='cuda:3', grad_fn=<MseLossBackward>)
# 130 / 178
#
# tensor(414.0461, device='cuda:3', grad_fn=<MseLossBackward>)
# 131 / 178
#
# tensor(40.8059, device='cuda:3', grad_fn=<MseLossBackward>)
# 132 / 178
#
# tensor(98.7612, device='cuda:3', grad_fn=<MseLossBackward>)
# 133 / 178
#
# tensor(263.3337, device='cuda:3', grad_fn=<MseLossBackward>)
# 134 / 178
#
# tensor(188.9348, device='cuda:3', grad_fn=<MseLossBackward>)
# 135 / 178
#
# tensor(280.0974, device='cuda:3', grad_fn=<MseLossBackward>)
# 136 / 178
#
# tensor(306.6085, device='cuda:3', grad_fn=<MseLossBackward>)
# 137 / 178
#
# tensor(59.0503, device='cuda:3', grad_fn=<MseLossBackward>)
# 138 / 178
#
# tensor(56.2568, device='cuda:3', grad_fn=<MseLossBackward>)
# 139 / 178
#
# tensor(72.0372, device='cuda:3', grad_fn=<MseLossBackward>)
# 140 / 178
#
# tensor(78.9381, device='cuda:3', grad_fn=<MseLossBackward>)
# 141 / 178
#
# tensor(113.1431, device='cuda:3', grad_fn=<MseLossBackward>)
# 142 / 178
#
# tensor(132.6892, device='cuda:3', grad_fn=<MseLossBackward>)
# 143 / 178
#
# tensor(323.7001, device='cuda:3', grad_fn=<MseLossBackward>)
# 144 / 178
#
# tensor(299.6303, device='cuda:3', grad_fn=<MseLossBackward>)
# 145 / 178
#
# tensor(291.6397, device='cuda:3', grad_fn=<MseLossBackward>)
# 146 / 178
#
# tensor(255.1623, device='cuda:3', grad_fn=<MseLossBackward>)
# 147 / 178
#
# tensor(432.1921, device='cuda:3', grad_fn=<MseLossBackward>)
# 148 / 178
#
# tensor(49.0726, device='cuda:3', grad_fn=<MseLossBackward>)
# 149 / 178
#
# tensor(68.8209, device='cuda:3', grad_fn=<MseLossBackward>)
# 150 / 178
#
# tensor(113.3865, device='cuda:3', grad_fn=<MseLossBackward>)
# 151 / 178
#
# tensor(104.4362, device='cuda:3', grad_fn=<MseLossBackward>)
# 152 / 178
#
# tensor(58.3979, device='cuda:3', grad_fn=<MseLossBackward>)
# 153 / 178
#
# tensor(49.0546, device='cuda:3', grad_fn=<MseLossBackward>)
# 154 / 178
#
# tensor(115.4348, device='cuda:3', grad_fn=<MseLossBackward>)
# 155 / 178
#
# tensor(79.4942, device='cuda:3', grad_fn=<MseLossBackward>)
# 156 / 178
#
# tensor(110.0823, device='cuda:3', grad_fn=<MseLossBackward>)
# 157 / 178
#
# tensor(200.3719, device='cuda:3', grad_fn=<MseLossBackward>)
# 158 / 178
#
# tensor(74.1837, device='cuda:3', grad_fn=<MseLossBackward>)
# 159 / 178
#
# tensor(73.6264, device='cuda:3', grad_fn=<MseLossBackward>)
# 160 / 178
#
# tensor(47.4941, device='cuda:3', grad_fn=<MseLossBackward>)
# 161 / 178
#
# tensor(212.9625, device='cuda:3', grad_fn=<MseLossBackward>)
# 162 / 178
#
# tensor(159.1059, device='cuda:3', grad_fn=<MseLossBackward>)
# 163 / 178
#
# tensor(145.3211, device='cuda:3', grad_fn=<MseLossBackward>)
# 164 / 178
#
# tensor(164.8664, device='cuda:3', grad_fn=<MseLossBackward>)
# 165 / 178
#
# tensor(126.8377, device='cuda:3', grad_fn=<MseLossBackward>)
# 166 / 178
#
# tensor(46.6826, device='cuda:3', grad_fn=<MseLossBackward>)
# 167 / 178
#
# tensor(76.5410, device='cuda:3', grad_fn=<MseLossBackward>)
# 168 / 178
#
# tensor(44.0650, device='cuda:3', grad_fn=<MseLossBackward>)
# 169 / 178
#
# tensor(170.1741, device='cuda:3', grad_fn=<MseLossBackward>)
# 170 / 178
#
# tensor(111.6673, device='cuda:3', grad_fn=<MseLossBackward>)
# 171 / 178
#
# tensor(148.1175, device='cuda:3', grad_fn=<MseLossBackward>)
# 172 / 178
#
# tensor(90.9268, device='cuda:3', grad_fn=<MseLossBackward>)
# 173 / 178
#
# tensor(99.3922, device='cuda:3', grad_fn=<MseLossBackward>)
# 174 / 178
#
# tensor(110.7433, device='cuda:3', grad_fn=<MseLossBackward>)
# 175 / 178
#
# tensor(158.1805, device='cuda:3', grad_fn=<MseLossBackward>)
# 176 / 178
#
# tensor(133.1625, device='cuda:3', grad_fn=<MseLossBackward>)
# 177 / 178

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
# %matplotlib inline



r2 = r2_score(iwi_true, iwi_pred)
print("r2: ", r2)

plt.figure(figsize=(10,10))
plt.scatter(iwi_true, iwi_pred, alpha=0.05, c='steelblue')
m, b = np.polyfit(iwi_true, iwi_pred, 1)

x = [i for i in range(101)]
y = [i*m + b for i in x]

print("slope: ", m, "intercept: ", b)

plt.title('MoCo Model \n ' + 'r2 = ' + str(round(r2, 4)) + '\n' + 'fold: ' + str(fold), fontsize=15)
plt.xlabel('True IWI', fontsize=20)
plt.ylabel('Predicted IWI', fontsize=20)
plt.plot(x, y, c='red')
# Out:
# r2:  0.5694593338186029
# slope:  0.5354555912630451 intercept:  11.157905747298454

# %%
lossf = criterion(torch.Tensor(iwi_pred), torch.Tensor(iwi_true))
lossf
# Out:
# tensor(160.6217)

# %%
with open('moco_pretrained/preds_{}.pkl'.format(fold), 'wb') as f:
    pkl.dump(iwi_pred, f)

# %%
iwi_pred_capped = []
for iwi in iwi_pred:
    if iwi < 100:
        iwi_pred_capped.append(iwi)
    else:
        iwi_pred_capped.append(100)
        
r2 = r2_score(iwi_true, iwi_pred_capped)
print("r2: ", r2)

plt.figure(figsize=(10,10))
plt.scatter(iwi_true, iwi_pred_capped, alpha=0.05, c='steelblue')
m, b = np.polyfit(iwi_true, iwi_pred, 1)

x = [i for i in range(101)]
y = [i*m + b for i in x]

print("slope: ", m, "intercept: ", b)

plt.title('r2 = ' + str(round(r2, 4)) + '\n' + 'fold: ' + str(fold), fontsize=15)
plt.xlabel('True IWI', fontsize=20)
plt.ylabel('Predicted IWI (capped at 100)', fontsize=20)
plt.plot(x, y, c='red')
# Out:
# r2:  0.5694593338186029
# slope:  0.5354555912630451 intercept:  11.157905747298454
