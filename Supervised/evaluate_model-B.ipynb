# %%
import torch
import pandas as pd
import numpy as np
import pickle as pkl

# %%
import supervised_dataset
import importlib
importlib.reload(supervised_dataset)
# Out:
# <module 'supervised_dataset' from '/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/Supervised/supervised_dataset.py'>

# %%
import sys
sys.path.insert(0, '/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/geography-aware-ssl/moco_fmow/moco')
from ms_nl_resnet import MS_NL_ResNet18
# Out:
# /cephyr/users/benvin/Alvis/.local/lib/python3.8/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension: /cephyr/users/benvin/Alvis/.local/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZNK3c106IValue23reportToTensorTypeErrorEv
#   warn(f"Failed to load image Python extension: {e}")

# %%
fold = 'B'
gpu = 1

losses = pd.read_csv('moco_pretrained/fold_{}/losses_fold_{}_epoch_0020_.txt'.format(fold, fold), sep=",", header=None)
best_epoch = losses[1].argmin()
print("Best epoch: ", best_epoch)
print("Best epoch val_loss: ", losses[1].iloc[best_epoch])

model = MS_NL_ResNet18(num_classes=1)
#optimizer = torch.optim.Adam(model.parameters(), lr=0.02)

## Supervised
checkpoint_path = 'moco_pretrained/fold_{}/checkpoint_fold_{}_{:04d}.pth.tar'.format(fold, fold, best_epoch)
print("Model loaded: ", checkpoint_path)
checkpoint = torch.load(checkpoint_path, map_location='cpu')

checkpoint_dict = dict()
for key in checkpoint['state_dict'].keys():
    resnet_key=key.replace("module.", "")
    checkpoint_dict[resnet_key]=checkpoint['state_dict'][key]

model.load_state_dict(checkpoint_dict)

loc = 'cuda:{}'.format(gpu)
checkpoint = torch.load('moco_pretrained/fold_{}/checkpoint_fold_{}_{:04d}.pth.tar'.format(fold, fold, best_epoch), map_location=loc)



#optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# Out:
# Best epoch:  10
# Best epoch val_loss:  142.38694581118497
# Model loaded:  moco_pretrained/fold_B/checkpoint_fold_B_0010.pth.tar

# %%
torch.cuda.set_device(0)
model.cuda(0)
print()

criterion = torch.nn.MSELoss().cuda(0)

# %%
csv = "/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/Supervised/dhs_clusters_paths.csv"
folds_path = '/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/CreateFolds/new_dhs_incountry_folds.pkl'


with open(folds_path, 'rb') as handle:
        folds = pkl.load(handle)
        
test_dataset = supervised_dataset.SupervisedDataset(csv, csv_indices=folds[fold]['test'])

batch_size = 64
test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# TEST MODEL
iwi_pred = []
iwi_true = []

model.eval()
for i, (images, labels) in enumerate(test_loader):
    #print(images.size())
    images = images.cuda(gpu)
    labels = labels.cuda(gpu)
    
    preds = model(images)
    preds = torch.squeeze(preds)
    #print(preds.size())
    
    loss = criterion(preds, labels)
    print(loss)
    
    for pred in preds:
        iwi_pred.append(pred.item())
    
    for label in labels:
        iwi_true.append(label.item())
    
    
    #iwi_preds.extend(preds.numpy())
    
    #print("batch: ", i)
    print(i, "/", len(test_loader))
    print()
# Out:
# tensor(216.1908, device='cuda:0', grad_fn=<MseLossBackward>)
# 0 / 178
#
# tensor(199.7629, device='cuda:0', grad_fn=<MseLossBackward>)
# 1 / 178
#
# tensor(200.4164, device='cuda:0', grad_fn=<MseLossBackward>)
# 2 / 178
#
# tensor(85.8711, device='cuda:0', grad_fn=<MseLossBackward>)
# 3 / 178
#
# tensor(108.2052, device='cuda:0', grad_fn=<MseLossBackward>)
# 4 / 178
#
# tensor(87.6335, device='cuda:0', grad_fn=<MseLossBackward>)
# 5 / 178
#
# tensor(65.7202, device='cuda:0', grad_fn=<MseLossBackward>)
# 6 / 178
#
# tensor(65.2183, device='cuda:0', grad_fn=<MseLossBackward>)
# 7 / 178
#
# tensor(71.8329, device='cuda:0', grad_fn=<MseLossBackward>)
# 8 / 178
#
# tensor(224.4458, device='cuda:0', grad_fn=<MseLossBackward>)
# 9 / 178
#
# tensor(208.5016, device='cuda:0', grad_fn=<MseLossBackward>)
# 10 / 178
#
# tensor(92.2107, device='cuda:0', grad_fn=<MseLossBackward>)
# 11 / 178
#
# tensor(122.3764, device='cuda:0', grad_fn=<MseLossBackward>)
# 12 / 178
#
# tensor(176.5772, device='cuda:0', grad_fn=<MseLossBackward>)
# 13 / 178
#
# tensor(128.8314, device='cuda:0', grad_fn=<MseLossBackward>)
# 14 / 178
#
# tensor(153.9587, device='cuda:0', grad_fn=<MseLossBackward>)
# 15 / 178
#
# tensor(161.9469, device='cuda:0', grad_fn=<MseLossBackward>)
# 16 / 178
#
# tensor(136.9814, device='cuda:0', grad_fn=<MseLossBackward>)
# 17 / 178
#
# tensor(157.8467, device='cuda:0', grad_fn=<MseLossBackward>)
# 18 / 178
#
# tensor(190.3731, device='cuda:0', grad_fn=<MseLossBackward>)
# 19 / 178
#
# tensor(147.4676, device='cuda:0', grad_fn=<MseLossBackward>)
# 20 / 178
#
# tensor(120.2662, device='cuda:0', grad_fn=<MseLossBackward>)
# 21 / 178
#
# tensor(136.7623, device='cuda:0', grad_fn=<MseLossBackward>)
# 22 / 178
#
# tensor(205.9008, device='cuda:0', grad_fn=<MseLossBackward>)
# 23 / 178
#
# tensor(202.9779, device='cuda:0', grad_fn=<MseLossBackward>)
# 24 / 178
#
# tensor(139.4026, device='cuda:0', grad_fn=<MseLossBackward>)
# 25 / 178
#
# tensor(60.3151, device='cuda:0', grad_fn=<MseLossBackward>)
# 26 / 178
#
# tensor(63.9464, device='cuda:0', grad_fn=<MseLossBackward>)
# 27 / 178
#
# tensor(71.6055, device='cuda:0', grad_fn=<MseLossBackward>)
# 28 / 178
#
# tensor(214.6152, device='cuda:0', grad_fn=<MseLossBackward>)
# 29 / 178
#
# tensor(135.9342, device='cuda:0', grad_fn=<MseLossBackward>)
# 30 / 178
#
# tensor(58.6383, device='cuda:0', grad_fn=<MseLossBackward>)
# 31 / 178
#
# tensor(180.6323, device='cuda:0', grad_fn=<MseLossBackward>)
# 32 / 178
#
# tensor(124.0585, device='cuda:0', grad_fn=<MseLossBackward>)
# 33 / 178
#
# tensor(50.0794, device='cuda:0', grad_fn=<MseLossBackward>)
# 34 / 178
#
# tensor(63.4716, device='cuda:0', grad_fn=<MseLossBackward>)
# 35 / 178
#
# tensor(112.7492, device='cuda:0', grad_fn=<MseLossBackward>)
# 36 / 178
#
# tensor(254.7358, device='cuda:0', grad_fn=<MseLossBackward>)
# 37 / 178
#
# tensor(68.1389, device='cuda:0', grad_fn=<MseLossBackward>)
# 38 / 178
#
# tensor(42.3380, device='cuda:0', grad_fn=<MseLossBackward>)
# 39 / 178
#
# tensor(65.2764, device='cuda:0', grad_fn=<MseLossBackward>)
# 40 / 178
#
# tensor(65.1618, device='cuda:0', grad_fn=<MseLossBackward>)
# 41 / 178
#
# tensor(56.4509, device='cuda:0', grad_fn=<MseLossBackward>)
# 42 / 178
#
# tensor(93.9605, device='cuda:0', grad_fn=<MseLossBackward>)
# 43 / 178
#
# tensor(134.1475, device='cuda:0', grad_fn=<MseLossBackward>)
# 44 / 178
#
# tensor(150.4685, device='cuda:0', grad_fn=<MseLossBackward>)
# 45 / 178
#
# tensor(107.6561, device='cuda:0', grad_fn=<MseLossBackward>)
# 46 / 178
#
# tensor(57.1397, device='cuda:0', grad_fn=<MseLossBackward>)
# 47 / 178
#
# tensor(72.6686, device='cuda:0', grad_fn=<MseLossBackward>)
# 48 / 178
#
# tensor(149.1414, device='cuda:0', grad_fn=<MseLossBackward>)
# 49 / 178
#
# tensor(110.9549, device='cuda:0', grad_fn=<MseLossBackward>)
# 50 / 178
#
# tensor(111.9002, device='cuda:0', grad_fn=<MseLossBackward>)
# 51 / 178
#
# tensor(82.0029, device='cuda:0', grad_fn=<MseLossBackward>)
# 52 / 178
#
# tensor(70.9683, device='cuda:0', grad_fn=<MseLossBackward>)
# 53 / 178
#
# tensor(120.2124, device='cuda:0', grad_fn=<MseLossBackward>)
# 54 / 178
#
# tensor(86.2415, device='cuda:0', grad_fn=<MseLossBackward>)
# 55 / 178
#
# tensor(91.9659, device='cuda:0', grad_fn=<MseLossBackward>)
# 56 / 178
#
# tensor(61.1114, device='cuda:0', grad_fn=<MseLossBackward>)
# 57 / 178
#
# tensor(79.0497, device='cuda:0', grad_fn=<MseLossBackward>)
# 58 / 178
#
# tensor(70.0957, device='cuda:0', grad_fn=<MseLossBackward>)
# 59 / 178
#
# tensor(63.4248, device='cuda:0', grad_fn=<MseLossBackward>)
# 60 / 178
#
# tensor(91.8163, device='cuda:0', grad_fn=<MseLossBackward>)
# 61 / 178
#
# tensor(68.7413, device='cuda:0', grad_fn=<MseLossBackward>)
# 62 / 178
#
# tensor(44.6740, device='cuda:0', grad_fn=<MseLossBackward>)
# 63 / 178
#
# tensor(100.7799, device='cuda:0', grad_fn=<MseLossBackward>)
# 64 / 178
#
# tensor(186.2239, device='cuda:0', grad_fn=<MseLossBackward>)
# 65 / 178
#
# tensor(89.5876, device='cuda:0', grad_fn=<MseLossBackward>)
# 66 / 178
#
# tensor(75.6858, device='cuda:0', grad_fn=<MseLossBackward>)
# 67 / 178
#
# tensor(94.1202, device='cuda:0', grad_fn=<MseLossBackward>)
# 68 / 178
#
# tensor(84.4330, device='cuda:0', grad_fn=<MseLossBackward>)
# 69 / 178
#
# tensor(102.5080, device='cuda:0', grad_fn=<MseLossBackward>)
# 70 / 178
#
# tensor(616.3687, device='cuda:0', grad_fn=<MseLossBackward>)
# 71 / 178
#
# tensor(394.8481, device='cuda:0', grad_fn=<MseLossBackward>)
# 72 / 178
#
# tensor(38.4566, device='cuda:0', grad_fn=<MseLossBackward>)
# 73 / 178
#
# tensor(86.2904, device='cuda:0', grad_fn=<MseLossBackward>)
# 74 / 178
#
# tensor(188.2733, device='cuda:0', grad_fn=<MseLossBackward>)
# 75 / 178
#
# tensor(175.6845, device='cuda:0', grad_fn=<MseLossBackward>)
# 76 / 178
#
# tensor(209.0035, device='cuda:0', grad_fn=<MseLossBackward>)
# 77 / 178
#
# tensor(384.4835, device='cuda:0', grad_fn=<MseLossBackward>)
# 78 / 178
#
# tensor(231.1055, device='cuda:0', grad_fn=<MseLossBackward>)
# 79 / 178
#
# tensor(191.9828, device='cuda:0', grad_fn=<MseLossBackward>)
# 80 / 178
#
# tensor(133.3758, device='cuda:0', grad_fn=<MseLossBackward>)
# 81 / 178
#
# tensor(107.0835, device='cuda:0', grad_fn=<MseLossBackward>)
# 82 / 178
#
# tensor(101.8036, device='cuda:0', grad_fn=<MseLossBackward>)
# 83 / 178
#
# tensor(177.3970, device='cuda:0', grad_fn=<MseLossBackward>)
# 84 / 178
#
# tensor(75.7337, device='cuda:0', grad_fn=<MseLossBackward>)
# 85 / 178
#
# tensor(97.0386, device='cuda:0', grad_fn=<MseLossBackward>)
# 86 / 178
#
# tensor(138.9021, device='cuda:0', grad_fn=<MseLossBackward>)
# 87 / 178
#
# tensor(119.9933, device='cuda:0', grad_fn=<MseLossBackward>)
# 88 / 178
#
# tensor(96.2849, device='cuda:0', grad_fn=<MseLossBackward>)
# 89 / 178
#
# tensor(108.1424, device='cuda:0', grad_fn=<MseLossBackward>)
# 90 / 178
#
# tensor(63.9687, device='cuda:0', grad_fn=<MseLossBackward>)
# 91 / 178
#
# tensor(45.9198, device='cuda:0', grad_fn=<MseLossBackward>)
# 92 / 178
#
# tensor(30.1127, device='cuda:0', grad_fn=<MseLossBackward>)
# 93 / 178
#
# tensor(130.9141, device='cuda:0', grad_fn=<MseLossBackward>)
# 94 / 178
#
# tensor(201.2454, device='cuda:0', grad_fn=<MseLossBackward>)
# 95 / 178
#
# tensor(172.4855, device='cuda:0', grad_fn=<MseLossBackward>)
# 96 / 178
#
# tensor(242.5570, device='cuda:0', grad_fn=<MseLossBackward>)
# 97 / 178
#
# tensor(82.7140, device='cuda:0', grad_fn=<MseLossBackward>)
# 98 / 178
#
# tensor(126.5248, device='cuda:0', grad_fn=<MseLossBackward>)
# 99 / 178
#
# tensor(121.6457, device='cuda:0', grad_fn=<MseLossBackward>)
# 100 / 178
#
# tensor(123.4925, device='cuda:0', grad_fn=<MseLossBackward>)
# 101 / 178
#
# tensor(86.5874, device='cuda:0', grad_fn=<MseLossBackward>)
# 102 / 178
#
# tensor(76.6063, device='cuda:0', grad_fn=<MseLossBackward>)
# 103 / 178
#
# tensor(132.1500, device='cuda:0', grad_fn=<MseLossBackward>)
# 104 / 178
#
# tensor(84.8367, device='cuda:0', grad_fn=<MseLossBackward>)
# 105 / 178
#
# tensor(107.6991, device='cuda:0', grad_fn=<MseLossBackward>)
# 106 / 178
#
# tensor(119.9261, device='cuda:0', grad_fn=<MseLossBackward>)
# 107 / 178
#
# tensor(126.5365, device='cuda:0', grad_fn=<MseLossBackward>)
# 108 / 178
#
# tensor(153.9890, device='cuda:0', grad_fn=<MseLossBackward>)
# 109 / 178
#
# tensor(151.8001, device='cuda:0', grad_fn=<MseLossBackward>)
# 110 / 178
#
# tensor(150.5265, device='cuda:0', grad_fn=<MseLossBackward>)
# 111 / 178
#
# tensor(150.3213, device='cuda:0', grad_fn=<MseLossBackward>)
# 112 / 178
#
# tensor(143.0625, device='cuda:0', grad_fn=<MseLossBackward>)
# 113 / 178
#
# tensor(120.2120, device='cuda:0', grad_fn=<MseLossBackward>)
# 114 / 178
#
# tensor(110.8881, device='cuda:0', grad_fn=<MseLossBackward>)
# 115 / 178
#
# tensor(145.2953, device='cuda:0', grad_fn=<MseLossBackward>)
# 116 / 178
#
# tensor(64.5369, device='cuda:0', grad_fn=<MseLossBackward>)
# 117 / 178
#
# tensor(60.4756, device='cuda:0', grad_fn=<MseLossBackward>)
# 118 / 178
#
# tensor(104.4596, device='cuda:0', grad_fn=<MseLossBackward>)
# 119 / 178
#
# tensor(53.6266, device='cuda:0', grad_fn=<MseLossBackward>)
# 120 / 178
#
# tensor(109.1387, device='cuda:0', grad_fn=<MseLossBackward>)
# 121 / 178
#
# tensor(485.1487, device='cuda:0', grad_fn=<MseLossBackward>)
# 122 / 178
#
# tensor(147.3575, device='cuda:0', grad_fn=<MseLossBackward>)
# 123 / 178
#
# tensor(227.3962, device='cuda:0', grad_fn=<MseLossBackward>)
# 124 / 178
#
# tensor(90.0593, device='cuda:0', grad_fn=<MseLossBackward>)
# 125 / 178
#
# tensor(243.2909, device='cuda:0', grad_fn=<MseLossBackward>)
# 126 / 178
#
# tensor(179.7199, device='cuda:0', grad_fn=<MseLossBackward>)
# 127 / 178
#
# tensor(355.5656, device='cuda:0', grad_fn=<MseLossBackward>)
# 128 / 178
#
# tensor(258.4189, device='cuda:0', grad_fn=<MseLossBackward>)
# 129 / 178
#
# tensor(245.0884, device='cuda:0', grad_fn=<MseLossBackward>)
# 130 / 178
#
# tensor(137.0686, device='cuda:0', grad_fn=<MseLossBackward>)
# 131 / 178
#
# tensor(255.7344, device='cuda:0', grad_fn=<MseLossBackward>)
# 132 / 178
#
# tensor(188.1260, device='cuda:0', grad_fn=<MseLossBackward>)
# 133 / 178
#
# tensor(169.3563, device='cuda:0', grad_fn=<MseLossBackward>)
# 134 / 178
#
# tensor(141.9586, device='cuda:0', grad_fn=<MseLossBackward>)
# 135 / 178
#
# tensor(139.4214, device='cuda:0', grad_fn=<MseLossBackward>)
# 136 / 178
#
# tensor(172.8521, device='cuda:0', grad_fn=<MseLossBackward>)
# 137 / 178
#
# tensor(195.8937, device='cuda:0', grad_fn=<MseLossBackward>)
# 138 / 178
#
# tensor(237.8617, device='cuda:0', grad_fn=<MseLossBackward>)
# 139 / 178
#
# tensor(77.4433, device='cuda:0', grad_fn=<MseLossBackward>)
# 140 / 178
#
# tensor(173.2060, device='cuda:0', grad_fn=<MseLossBackward>)
# 141 / 178
#
# tensor(186.1397, device='cuda:0', grad_fn=<MseLossBackward>)
# 142 / 178
#
# tensor(177.9967, device='cuda:0', grad_fn=<MseLossBackward>)
# 143 / 178
#
# tensor(186.3657, device='cuda:0', grad_fn=<MseLossBackward>)
# 144 / 178
#
# tensor(92.2716, device='cuda:0', grad_fn=<MseLossBackward>)
# 145 / 178
#
# tensor(73.6269, device='cuda:0', grad_fn=<MseLossBackward>)
# 146 / 178
#
# tensor(82.0329, device='cuda:0', grad_fn=<MseLossBackward>)
# 147 / 178
#
# tensor(101.9620, device='cuda:0', grad_fn=<MseLossBackward>)
# 148 / 178
#
# tensor(90.9965, device='cuda:0', grad_fn=<MseLossBackward>)
# 149 / 178
#
# tensor(103.8604, device='cuda:0', grad_fn=<MseLossBackward>)
# 150 / 178
#
# tensor(284.0720, device='cuda:0', grad_fn=<MseLossBackward>)
# 151 / 178
#
# tensor(169.3370, device='cuda:0', grad_fn=<MseLossBackward>)
# 152 / 178
#
# tensor(126.4962, device='cuda:0', grad_fn=<MseLossBackward>)
# 153 / 178
#
# tensor(161.1068, device='cuda:0', grad_fn=<MseLossBackward>)
# 154 / 178
#
# tensor(131.4747, device='cuda:0', grad_fn=<MseLossBackward>)
# 155 / 178
#
# tensor(126.5374, device='cuda:0', grad_fn=<MseLossBackward>)
# 156 / 178
#
# tensor(103.1901, device='cuda:0', grad_fn=<MseLossBackward>)
# 157 / 178
#
# tensor(222.8110, device='cuda:0', grad_fn=<MseLossBackward>)
# 158 / 178
#
# tensor(166.3409, device='cuda:0', grad_fn=<MseLossBackward>)
# 159 / 178
#
# tensor(98.3783, device='cuda:0', grad_fn=<MseLossBackward>)
# 160 / 178
#
# tensor(107.4914, device='cuda:0', grad_fn=<MseLossBackward>)
# 161 / 178
#
# tensor(102.6066, device='cuda:0', grad_fn=<MseLossBackward>)
# 162 / 178
#
# tensor(62.5779, device='cuda:0', grad_fn=<MseLossBackward>)
# 163 / 178
#
# tensor(126.5418, device='cuda:0', grad_fn=<MseLossBackward>)
# 164 / 178
#
# tensor(134.5461, device='cuda:0', grad_fn=<MseLossBackward>)
# 165 / 178
#
# tensor(154.2859, device='cuda:0', grad_fn=<MseLossBackward>)
# 166 / 178
#
# tensor(128.9373, device='cuda:0', grad_fn=<MseLossBackward>)
# 167 / 178
#
# tensor(83.6700, device='cuda:0', grad_fn=<MseLossBackward>)
# 168 / 178
#
# tensor(75.9762, device='cuda:0', grad_fn=<MseLossBackward>)
# 169 / 178
#
# tensor(174.5771, device='cuda:0', grad_fn=<MseLossBackward>)
# 170 / 178
#
# tensor(131.6311, device='cuda:0', grad_fn=<MseLossBackward>)
# 171 / 178
#
# tensor(190.1544, device='cuda:0', grad_fn=<MseLossBackward>)
# 172 / 178
#
# tensor(143.8482, device='cuda:0', grad_fn=<MseLossBackward>)
# 173 / 178
#
# tensor(121.6813, device='cuda:0', grad_fn=<MseLossBackward>)
# 174 / 178
#
# tensor(101.3269, device='cuda:0', grad_fn=<MseLossBackward>)
# 175 / 178
#
# tensor(74.2712, device='cuda:0', grad_fn=<MseLossBackward>)
# 176 / 178
#
# tensor(99.8760, device='cuda:0', grad_fn=<MseLossBackward>)
# 177 / 178

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
# %matplotlib inline



r2 = r2_score(iwi_true, iwi_pred)
print("r2: ", r2)

plt.figure(figsize=(10,10))
plt.scatter(iwi_true, iwi_pred, alpha=0.05, c='steelblue')
m, b = np.polyfit(iwi_true, iwi_pred, 1)

x = [i for i in range(101)]
y = [i*m + b for i in x]

print("slope: ", m, "intercept: ", b)

plt.title('MoCo Model \n ' + 'r2 = ' + str(round(r2, 4)) + '\n' + 'fold: ' + str(fold), fontsize=15)
plt.xlabel('True IWI', fontsize=20)
plt.ylabel('Predicted IWI', fontsize=20)
plt.plot(x, y, c='red')
# Out:
# r2:  0.6709601444800364
# slope:  0.6024646290662097 intercept:  16.366597427879054

# %%
lossf = criterion(torch.Tensor(iwi_pred), torch.Tensor(iwi_true))
lossf
# Out:
# tensor(109.5642)

# %%
with open('moco_pretrained/preds_{}.pkl'.format(fold), 'wb') as f:
    pkl.dump(iwi_pred, f)

# %%
iwi_pred_capped = []
for iwi in iwi_pred:
    if iwi < 100:
        iwi_pred_capped.append(iwi)
    else:
        iwi_pred_capped.append(100)
        
r2 = r2_score(iwi_true, iwi_pred_capped)
print("r2: ", r2)

plt.figure(figsize=(10,10))
plt.scatter(iwi_true, iwi_pred_capped, alpha=0.05, c='steelblue')
m, b = np.polyfit(iwi_true, iwi_pred, 1)

x = [i for i in range(101)]
y = [i*m + b for i in x]

print("slope: ", m, "intercept: ", b)

plt.title('r2 = ' + str(round(r2, 4)) + '\n' + 'fold: ' + str(fold), fontsize=15)
plt.xlabel('True IWI', fontsize=20)
plt.ylabel('Predicted IWI (capped at 100)', fontsize=20)
plt.plot(x, y, c='red')
# Out:
# r2:  0.6710065304043917
# slope:  0.6024646290662097 intercept:  16.366597427879054
