# %%
import torch
import pandas as pd
import numpy as np
import pickle as pkl

# %%
import supervised_dataset
import importlib
importlib.reload(supervised_dataset)
# Out:
# <module 'supervised_dataset' from '/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/Supervised/supervised_dataset.py'>

# %%
import sys
sys.path.insert(0, '/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/geography-aware-ssl/moco_fmow/moco')
from ms_nl_resnet import MS_NL_ResNet18
# Out:
# /cephyr/users/benvin/Alvis/.local/lib/python3.8/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension: /cephyr/users/benvin/Alvis/.local/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZNK3c106IValue23reportToTensorTypeErrorEv
#   warn(f"Failed to load image Python extension: {e}")

# %%
fold = 'D'
gpu = 2

losses = pd.read_csv('moco_pretrained/fold_{}/losses_fold_{}_epoch_0020_.txt'.format(fold, fold), sep=",", header=None)
best_epoch = losses[1].argmin()
print("Best epoch: ", best_epoch)
print("Best epoch val_loss: ", losses[1].iloc[best_epoch])

model = MS_NL_ResNet18(num_classes=1)
#optimizer = torch.optim.Adam(model.parameters(), lr=0.02)

## Supervised
checkpoint_path = 'moco_pretrained/fold_{}/checkpoint_fold_{}_{:04d}.pth.tar'.format(fold, fold, best_epoch)
print("Model loaded: ", checkpoint_path)
checkpoint = torch.load(checkpoint_path, map_location='cpu')

checkpoint_dict = dict()
for key in checkpoint['state_dict'].keys():
    resnet_key=key.replace("module.", "")
    checkpoint_dict[resnet_key]=checkpoint['state_dict'][key]

model.load_state_dict(checkpoint_dict)

loc = 'cuda:{}'.format(gpu)
checkpoint = torch.load('moco_pretrained/fold_{}/checkpoint_fold_{}_{:04d}.pth.tar'.format(fold, fold, best_epoch), map_location=loc)



#optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# Out:
# Best epoch:  4
# Best epoch val_loss:  152.93799131566828
# Model loaded:  moco_pretrained/fold_D/checkpoint_fold_D_0004.pth.tar

# %%
torch.cuda.set_device(gpu)
model.cuda(gpu)
print()

criterion = torch.nn.MSELoss().cuda(gpu)

# %%
csv = "/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/Supervised/dhs_clusters_paths.csv"
folds_path = '/cephyr/NOBACKUP/groups/globalpoverty1/JesperBenjamin/CreateFolds/new_dhs_incountry_folds.pkl'


with open(folds_path, 'rb') as handle:
        folds = pkl.load(handle)
        
test_dataset = supervised_dataset.SupervisedDataset(csv, csv_indices=folds[fold]['test'])

batch_size = 64
test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# TEST MODEL
iwi_pred = []
iwi_true = []

model.eval()
for i, (images, labels) in enumerate(test_loader):
    #print(images.size())
    images = images.cuda(gpu)
    labels = labels.cuda(gpu)
    
    preds = model(images)
    preds = torch.squeeze(preds)
    #print(preds.size())
    
    loss = criterion(preds, labels)
    print(loss)
    
    for pred in preds:
        iwi_pred.append(pred.item())
    
    for label in labels:
        iwi_true.append(label.item())
    
    
    #iwi_preds.extend(preds.numpy())
    
    #print("batch: ", i)
    print(i, "/", len(test_loader))
    print()
# Out:
# tensor(342.4674, device='cuda:2', grad_fn=<MseLossBackward>)
# 0 / 178
#
# tensor(286.4752, device='cuda:2', grad_fn=<MseLossBackward>)
# 1 / 178
#
# tensor(226.7416, device='cuda:2', grad_fn=<MseLossBackward>)
# 2 / 178
#
# tensor(104.7905, device='cuda:2', grad_fn=<MseLossBackward>)
# 3 / 178
#
# tensor(72.7639, device='cuda:2', grad_fn=<MseLossBackward>)
# 4 / 178
#
# tensor(64.7918, device='cuda:2', grad_fn=<MseLossBackward>)
# 5 / 178
#
# tensor(56.0718, device='cuda:2', grad_fn=<MseLossBackward>)
# 6 / 178
#
# tensor(51.6367, device='cuda:2', grad_fn=<MseLossBackward>)
# 7 / 178
#
# tensor(66.8742, device='cuda:2', grad_fn=<MseLossBackward>)
# 8 / 178
#
# tensor(222.9107, device='cuda:2', grad_fn=<MseLossBackward>)
# 9 / 178
#
# tensor(203.8199, device='cuda:2', grad_fn=<MseLossBackward>)
# 10 / 178
#
# tensor(65.0871, device='cuda:2', grad_fn=<MseLossBackward>)
# 11 / 178
#
# tensor(43.0397, device='cuda:2', grad_fn=<MseLossBackward>)
# 12 / 178
#
# tensor(53.6487, device='cuda:2', grad_fn=<MseLossBackward>)
# 13 / 178
#
# tensor(48.5764, device='cuda:2', grad_fn=<MseLossBackward>)
# 14 / 178
#
# tensor(59.8522, device='cuda:2', grad_fn=<MseLossBackward>)
# 15 / 178
#
# tensor(81.6998, device='cuda:2', grad_fn=<MseLossBackward>)
# 16 / 178
#
# tensor(59.2236, device='cuda:2', grad_fn=<MseLossBackward>)
# 17 / 178
#
# tensor(24.7163, device='cuda:2', grad_fn=<MseLossBackward>)
# 18 / 178
#
# tensor(55.9360, device='cuda:2', grad_fn=<MseLossBackward>)
# 19 / 178
#
# tensor(61.0175, device='cuda:2', grad_fn=<MseLossBackward>)
# 20 / 178
#
# tensor(57.5385, device='cuda:2', grad_fn=<MseLossBackward>)
# 21 / 178
#
# tensor(93.4566, device='cuda:2', grad_fn=<MseLossBackward>)
# 22 / 178
#
# tensor(42.4338, device='cuda:2', grad_fn=<MseLossBackward>)
# 23 / 178
#
# tensor(49.4765, device='cuda:2', grad_fn=<MseLossBackward>)
# 24 / 178
#
# tensor(66.0967, device='cuda:2', grad_fn=<MseLossBackward>)
# 25 / 178
#
# tensor(22.9651, device='cuda:2', grad_fn=<MseLossBackward>)
# 26 / 178
#
# tensor(48.4131, device='cuda:2', grad_fn=<MseLossBackward>)
# 27 / 178
#
# tensor(81.4622, device='cuda:2', grad_fn=<MseLossBackward>)
# 28 / 178
#
# tensor(194.4525, device='cuda:2', grad_fn=<MseLossBackward>)
# 29 / 178
#
# tensor(39.0184, device='cuda:2', grad_fn=<MseLossBackward>)
# 30 / 178
#
# tensor(83.2573, device='cuda:2', grad_fn=<MseLossBackward>)
# 31 / 178
#
# tensor(154.4521, device='cuda:2', grad_fn=<MseLossBackward>)
# 32 / 178
#
# tensor(148.2260, device='cuda:2', grad_fn=<MseLossBackward>)
# 33 / 178
#
# tensor(114.3583, device='cuda:2', grad_fn=<MseLossBackward>)
# 34 / 178
#
# tensor(98.0753, device='cuda:2', grad_fn=<MseLossBackward>)
# 35 / 178
#
# tensor(69.7497, device='cuda:2', grad_fn=<MseLossBackward>)
# 36 / 178
#
# tensor(100.2031, device='cuda:2', grad_fn=<MseLossBackward>)
# 37 / 178
#
# tensor(184.1870, device='cuda:2', grad_fn=<MseLossBackward>)
# 38 / 178
#
# tensor(90.4653, device='cuda:2', grad_fn=<MseLossBackward>)
# 39 / 178
#
# tensor(106.5460, device='cuda:2', grad_fn=<MseLossBackward>)
# 40 / 178
#
# tensor(116.4035, device='cuda:2', grad_fn=<MseLossBackward>)
# 41 / 178
#
# tensor(192.0570, device='cuda:2', grad_fn=<MseLossBackward>)
# 42 / 178
#
# tensor(183.3352, device='cuda:2', grad_fn=<MseLossBackward>)
# 43 / 178
#
# tensor(122.5485, device='cuda:2', grad_fn=<MseLossBackward>)
# 44 / 178
#
# tensor(178.0869, device='cuda:2', grad_fn=<MseLossBackward>)
# 45 / 178
#
# tensor(72.6789, device='cuda:2', grad_fn=<MseLossBackward>)
# 46 / 178
#
# tensor(89.6682, device='cuda:2', grad_fn=<MseLossBackward>)
# 47 / 178
#
# tensor(106.6461, device='cuda:2', grad_fn=<MseLossBackward>)
# 48 / 178
#
# tensor(202.8920, device='cuda:2', grad_fn=<MseLossBackward>)
# 49 / 178
#
# tensor(169.6042, device='cuda:2', grad_fn=<MseLossBackward>)
# 50 / 178
#
# tensor(86.7586, device='cuda:2', grad_fn=<MseLossBackward>)
# 51 / 178
#
# tensor(181.7188, device='cuda:2', grad_fn=<MseLossBackward>)
# 52 / 178
#
# tensor(499.7890, device='cuda:2', grad_fn=<MseLossBackward>)
# 53 / 178
#
# tensor(158.2674, device='cuda:2', grad_fn=<MseLossBackward>)
# 54 / 178
#
# tensor(228.9090, device='cuda:2', grad_fn=<MseLossBackward>)
# 55 / 178
#
# tensor(205.5349, device='cuda:2', grad_fn=<MseLossBackward>)
# 56 / 178
#
# tensor(123.8983, device='cuda:2', grad_fn=<MseLossBackward>)
# 57 / 178
#
# tensor(109.4281, device='cuda:2', grad_fn=<MseLossBackward>)
# 58 / 178
#
# tensor(171.2399, device='cuda:2', grad_fn=<MseLossBackward>)
# 59 / 178
#
# tensor(217.7409, device='cuda:2', grad_fn=<MseLossBackward>)
# 60 / 178
#
# tensor(170.7877, device='cuda:2', grad_fn=<MseLossBackward>)
# 61 / 178
#
# tensor(230.8146, device='cuda:2', grad_fn=<MseLossBackward>)
# 62 / 178
#
# tensor(119.8029, device='cuda:2', grad_fn=<MseLossBackward>)
# 63 / 178
#
# tensor(55.4239, device='cuda:2', grad_fn=<MseLossBackward>)
# 64 / 178
#
# tensor(123.4182, device='cuda:2', grad_fn=<MseLossBackward>)
# 65 / 178
#
# tensor(323.5586, device='cuda:2', grad_fn=<MseLossBackward>)
# 66 / 178
#
# tensor(181.6914, device='cuda:2', grad_fn=<MseLossBackward>)
# 67 / 178
#
# tensor(251.6647, device='cuda:2', grad_fn=<MseLossBackward>)
# 68 / 178
#
# tensor(460.6708, device='cuda:2', grad_fn=<MseLossBackward>)
# 69 / 178
#
# tensor(182.1651, device='cuda:2', grad_fn=<MseLossBackward>)
# 70 / 178
#
# tensor(84.1468, device='cuda:2', grad_fn=<MseLossBackward>)
# 71 / 178
#
# tensor(102.6654, device='cuda:2', grad_fn=<MseLossBackward>)
# 72 / 178
#
# tensor(108.2915, device='cuda:2', grad_fn=<MseLossBackward>)
# 73 / 178
#
# tensor(174.5127, device='cuda:2', grad_fn=<MseLossBackward>)
# 74 / 178
#
# tensor(118.4059, device='cuda:2', grad_fn=<MseLossBackward>)
# 75 / 178
#
# tensor(77.3525, device='cuda:2', grad_fn=<MseLossBackward>)
# 76 / 178
#
# tensor(116.5681, device='cuda:2', grad_fn=<MseLossBackward>)
# 77 / 178
#
# tensor(195.7581, device='cuda:2', grad_fn=<MseLossBackward>)
# 78 / 178
#
# tensor(140.4943, device='cuda:2', grad_fn=<MseLossBackward>)
# 79 / 178
#
# tensor(94.9832, device='cuda:2', grad_fn=<MseLossBackward>)
# 80 / 178
#
# tensor(135.9169, device='cuda:2', grad_fn=<MseLossBackward>)
# 81 / 178
#
# tensor(64.1066, device='cuda:2', grad_fn=<MseLossBackward>)
# 82 / 178
#
# tensor(132.8307, device='cuda:2', grad_fn=<MseLossBackward>)
# 83 / 178
#
# tensor(148.9441, device='cuda:2', grad_fn=<MseLossBackward>)
# 84 / 178
#
# tensor(51.8523, device='cuda:2', grad_fn=<MseLossBackward>)
# 85 / 178
#
# tensor(112.7535, device='cuda:2', grad_fn=<MseLossBackward>)
# 86 / 178
#
# tensor(78.1954, device='cuda:2', grad_fn=<MseLossBackward>)
# 87 / 178
#
# tensor(82.2598, device='cuda:2', grad_fn=<MseLossBackward>)
# 88 / 178
#
# tensor(99.6755, device='cuda:2', grad_fn=<MseLossBackward>)
# 89 / 178
#
# tensor(125.5941, device='cuda:2', grad_fn=<MseLossBackward>)
# 90 / 178
#
# tensor(99.6409, device='cuda:2', grad_fn=<MseLossBackward>)
# 91 / 178
#
# tensor(115.9797, device='cuda:2', grad_fn=<MseLossBackward>)
# 92 / 178
#
# tensor(47.4453, device='cuda:2', grad_fn=<MseLossBackward>)
# 93 / 178
#
# tensor(109.0811, device='cuda:2', grad_fn=<MseLossBackward>)
# 94 / 178
#
# tensor(105.7850, device='cuda:2', grad_fn=<MseLossBackward>)
# 95 / 178
#
# tensor(115.5889, device='cuda:2', grad_fn=<MseLossBackward>)
# 96 / 178
#
# tensor(77.4112, device='cuda:2', grad_fn=<MseLossBackward>)
# 97 / 178
#
# tensor(87.7984, device='cuda:2', grad_fn=<MseLossBackward>)
# 98 / 178
#
# tensor(151.9283, device='cuda:2', grad_fn=<MseLossBackward>)
# 99 / 178
#
# tensor(156.7301, device='cuda:2', grad_fn=<MseLossBackward>)
# 100 / 178
#
# tensor(113.1693, device='cuda:2', grad_fn=<MseLossBackward>)
# 101 / 178
#
# tensor(126.0926, device='cuda:2', grad_fn=<MseLossBackward>)
# 102 / 178
#
# tensor(121.0465, device='cuda:2', grad_fn=<MseLossBackward>)
# 103 / 178
#
# tensor(132.9808, device='cuda:2', grad_fn=<MseLossBackward>)
# 104 / 178
#
# tensor(189.5427, device='cuda:2', grad_fn=<MseLossBackward>)
# 105 / 178
#
# tensor(128.0640, device='cuda:2', grad_fn=<MseLossBackward>)
# 106 / 178
#
# tensor(128.4084, device='cuda:2', grad_fn=<MseLossBackward>)
# 107 / 178
#
# tensor(85.8098, device='cuda:2', grad_fn=<MseLossBackward>)
# 108 / 178
#
# tensor(50.4755, device='cuda:2', grad_fn=<MseLossBackward>)
# 109 / 178
#
# tensor(68.9386, device='cuda:2', grad_fn=<MseLossBackward>)
# 110 / 178
#
# tensor(116.0273, device='cuda:2', grad_fn=<MseLossBackward>)
# 111 / 178
#
# tensor(67.5097, device='cuda:2', grad_fn=<MseLossBackward>)
# 112 / 178
#
# tensor(37.6918, device='cuda:2', grad_fn=<MseLossBackward>)
# 113 / 178
#
# tensor(114.6942, device='cuda:2', grad_fn=<MseLossBackward>)
# 114 / 178
#
# tensor(618.5739, device='cuda:2', grad_fn=<MseLossBackward>)
# 115 / 178
#
# tensor(373.5087, device='cuda:2', grad_fn=<MseLossBackward>)
# 116 / 178
#
# tensor(202.0803, device='cuda:2', grad_fn=<MseLossBackward>)
# 117 / 178
#
# tensor(140.4163, device='cuda:2', grad_fn=<MseLossBackward>)
# 118 / 178
#
# tensor(112.1165, device='cuda:2', grad_fn=<MseLossBackward>)
# 119 / 178
#
# tensor(292.0682, device='cuda:2', grad_fn=<MseLossBackward>)
# 120 / 178
#
# tensor(303.5477, device='cuda:2', grad_fn=<MseLossBackward>)
# 121 / 178
#
# tensor(314.3838, device='cuda:2', grad_fn=<MseLossBackward>)
# 122 / 178
#
# tensor(319.1536, device='cuda:2', grad_fn=<MseLossBackward>)
# 123 / 178
#
# tensor(289.5386, device='cuda:2', grad_fn=<MseLossBackward>)
# 124 / 178
#
# tensor(127.7088, device='cuda:2', grad_fn=<MseLossBackward>)
# 125 / 178
#
# tensor(177.4236, device='cuda:2', grad_fn=<MseLossBackward>)
# 126 / 178
#
# tensor(89.9691, device='cuda:2', grad_fn=<MseLossBackward>)
# 127 / 178
#
# tensor(136.0336, device='cuda:2', grad_fn=<MseLossBackward>)
# 128 / 178
#
# tensor(149.7561, device='cuda:2', grad_fn=<MseLossBackward>)
# 129 / 178
#
# tensor(159.2819, device='cuda:2', grad_fn=<MseLossBackward>)
# 130 / 178
#
# tensor(293.1670, device='cuda:2', grad_fn=<MseLossBackward>)
# 131 / 178
#
# tensor(150.2829, device='cuda:2', grad_fn=<MseLossBackward>)
# 132 / 178
#
# tensor(47.5476, device='cuda:2', grad_fn=<MseLossBackward>)
# 133 / 178
#
# tensor(38.6171, device='cuda:2', grad_fn=<MseLossBackward>)
# 134 / 178
#
# tensor(29.1189, device='cuda:2', grad_fn=<MseLossBackward>)
# 135 / 178
#
# tensor(73.8920, device='cuda:2', grad_fn=<MseLossBackward>)
# 136 / 178
#
# tensor(21.5612, device='cuda:2', grad_fn=<MseLossBackward>)
# 137 / 178
#
# tensor(61.4646, device='cuda:2', grad_fn=<MseLossBackward>)
# 138 / 178
#
# tensor(68.1173, device='cuda:2', grad_fn=<MseLossBackward>)
# 139 / 178
#
# tensor(87.3285, device='cuda:2', grad_fn=<MseLossBackward>)
# 140 / 178
#
# tensor(62.4634, device='cuda:2', grad_fn=<MseLossBackward>)
# 141 / 178
#
# tensor(90.7761, device='cuda:2', grad_fn=<MseLossBackward>)
# 142 / 178
#
# tensor(155.0745, device='cuda:2', grad_fn=<MseLossBackward>)
# 143 / 178
#
# tensor(110.4574, device='cuda:2', grad_fn=<MseLossBackward>)
# 144 / 178
#
# tensor(135.6418, device='cuda:2', grad_fn=<MseLossBackward>)
# 145 / 178
#
# tensor(272.3951, device='cuda:2', grad_fn=<MseLossBackward>)
# 146 / 178
#
# tensor(180.1524, device='cuda:2', grad_fn=<MseLossBackward>)
# 147 / 178
#
# tensor(350.2365, device='cuda:2', grad_fn=<MseLossBackward>)
# 148 / 178
#
# tensor(396.2411, device='cuda:2', grad_fn=<MseLossBackward>)
# 149 / 178
#
# tensor(95.5835, device='cuda:2', grad_fn=<MseLossBackward>)
# 150 / 178
#
# tensor(56.8501, device='cuda:2', grad_fn=<MseLossBackward>)
# 151 / 178
#
# tensor(113.5380, device='cuda:2', grad_fn=<MseLossBackward>)
# 152 / 178
#
# tensor(162.1648, device='cuda:2', grad_fn=<MseLossBackward>)
# 153 / 178
#
# tensor(464.9164, device='cuda:2', grad_fn=<MseLossBackward>)
# 154 / 178
#
# tensor(456.9924, device='cuda:2', grad_fn=<MseLossBackward>)
# 155 / 178
#
# tensor(103.7502, device='cuda:2', grad_fn=<MseLossBackward>)
# 156 / 178
#
# tensor(115.4760, device='cuda:2', grad_fn=<MseLossBackward>)
# 157 / 178
#
# tensor(80.2994, device='cuda:2', grad_fn=<MseLossBackward>)
# 158 / 178
#
# tensor(226.5157, device='cuda:2', grad_fn=<MseLossBackward>)
# 159 / 178
#
# tensor(116.3665, device='cuda:2', grad_fn=<MseLossBackward>)
# 160 / 178
#
# tensor(150.7316, device='cuda:2', grad_fn=<MseLossBackward>)
# 161 / 178
#
# tensor(109.9685, device='cuda:2', grad_fn=<MseLossBackward>)
# 162 / 178
#
# tensor(180.4705, device='cuda:2', grad_fn=<MseLossBackward>)
# 163 / 178
#
# tensor(97.2878, device='cuda:2', grad_fn=<MseLossBackward>)
# 164 / 178
#
# tensor(67.2099, device='cuda:2', grad_fn=<MseLossBackward>)
# 165 / 178
#
# tensor(63.2734, device='cuda:2', grad_fn=<MseLossBackward>)
# 166 / 178
#
# tensor(108.2494, device='cuda:2', grad_fn=<MseLossBackward>)
# 167 / 178
#
# tensor(156.4390, device='cuda:2', grad_fn=<MseLossBackward>)
# 168 / 178
#
# tensor(108.6595, device='cuda:2', grad_fn=<MseLossBackward>)
# 169 / 178
#
# tensor(163.2505, device='cuda:2', grad_fn=<MseLossBackward>)
# 170 / 178
#
# tensor(109.1671, device='cuda:2', grad_fn=<MseLossBackward>)
# 171 / 178
#
# tensor(85.6676, device='cuda:2', grad_fn=<MseLossBackward>)
# 172 / 178
#
# tensor(129.5095, device='cuda:2', grad_fn=<MseLossBackward>)
# 173 / 178
#
# tensor(97.6521, device='cuda:2', grad_fn=<MseLossBackward>)
# 174 / 178
#
# tensor(48.2128, device='cuda:2', grad_fn=<MseLossBackward>)
# 175 / 178
#
# tensor(102.7810, device='cuda:2', grad_fn=<MseLossBackward>)
# 176 / 178
#
# tensor(87.0016, device='cuda:2', grad_fn=<MseLossBackward>)
# 177 / 178

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
# %matplotlib inline



r2 = r2_score(iwi_true, iwi_pred)
print("r2: ", r2)

plt.figure(figsize=(10,10))
plt.scatter(iwi_true, iwi_pred, alpha=0.05, c='steelblue')
m, b = np.polyfit(iwi_true, iwi_pred, 1)

x = [i for i in range(101)]
y = [i*m + b for i in x]

print("slope: ", m, "intercept: ", b)

plt.title('MoCo Model \n ' + 'r2 = ' + str(round(r2, 4)) + '\n' + 'fold: ' + str(fold), fontsize=15)
plt.xlabel('True IWI', fontsize=20)
plt.ylabel('Predicted IWI', fontsize=20)
plt.plot(x, y, c='red')
# Out:
# r2:  0.5799412337795204
# slope:  0.5881989015509095 intercept:  12.718135066958226

# %%
lossf = criterion(torch.Tensor(iwi_pred), torch.Tensor(iwi_true))
lossf
# Out:
# tensor(138.9068)

# %%
with open('moco_pretrained/preds_{}.pkl'.format(fold), 'wb') as f:
    pkl.dump(iwi_pred, f)

# %%
iwi_pred_capped = []
for iwi in iwi_pred:
    if iwi < 100:
        iwi_pred_capped.append(iwi)
    else:
        iwi_pred_capped.append(100)
        
r2 = r2_score(iwi_true, iwi_pred_capped)
print("r2: ", r2)

plt.figure(figsize=(10,10))
plt.scatter(iwi_true, iwi_pred_capped, alpha=0.05, c='steelblue')
m, b = np.polyfit(iwi_true, iwi_pred, 1)

x = [i for i in range(101)]
y = [i*m + b for i in x]

print("slope: ", m, "intercept: ", b)

plt.title('r2 = ' + str(round(r2, 4)) + '\n' + 'fold: ' + str(fold), fontsize=15)
plt.xlabel('True IWI', fontsize=20)
plt.ylabel('Predicted IWI (capped at 100)', fontsize=20)
plt.plot(x, y, c='red')
