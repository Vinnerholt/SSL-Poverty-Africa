# %% [markdown]
# # Split large clusters

# %%
# !pip install shapely
# Out:
# Collecting shapely
#   Downloading Shapely-1.7.1-cp37-cp37m-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 1.1 MB/s eta 0:00:01
# Installing collected packages: shapely
# Successfully installed shapely-1.7.1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import json
from shapely.geometry import Point, Polygon
from utils.geo_plot import setup_ax, plot_locs
from preprocessing.create_folds import (
    create_folds,
    create_split_folds,
    save_folds,
    verify_folds)

# %%
dhs_df = pd.read_csv('../dhs_clusters.csv', float_precision='high', index_col=False)
dhs_locs = dhs_df[['lat', 'lon']].values
FOLDS = ['A', 'B', 'C', 'D', 'E']
MIN_DIST = 0.096198
with open('dhs_incountry_folds.pkl', 'rb') as f:
    dhs_incountry_folds = pickle.load(f)

# %%
def plot_splits(locs_dict, title=None):
    '''
    Args
    - locs_dict: dict, label (str) => np.array of lat, lon
    '''
    fig = plt.figure(figsize=[15, 15])
    ax = setup_ax(fig)

    for label, locs_array in locs_dict.items():
        ax.scatter(locs_array[:, 1], locs_array[:, 0], label=label, s=2)

    lgd = ax.legend()
    for handle in lgd.legendHandles:
        handle.set_sizes([50.0])

    if title is not None:
        ax.set_title(title)
    plt.show()

# %% [markdown]
# Create in-country folds:

# %%
dhs_incountry_test_folds = create_folds(
    locs=dhs_locs,
    min_dist=MIN_DIST,
    fold_names=FOLDS,
    plot_largest_clusters=5)

verify_folds(
    folds=dhs_incountry_test_folds,
    locs=dhs_locs,
    min_dist=MIN_DIST,
    max_index=len(dhs_locs))

new_dhs_incountry_folds = create_split_folds(
    test_folds=dhs_incountry_test_folds,
    fold_names=FOLDS)
# Out:
# num clusters: 4053
# num outliers: 6652
# max cluster size (excl. outliers): 6712
# Size of each fold
# {'A': 11439, 'B': 11439, 'C': 11439, 'D': 11439, 'E': 11439}
# Minimum distance between each pair of folds
# A B 0.09635244480943116
# A C 0.09624439466781931
# A D 0.09631040779686083
# A E 0.09623030720619782
# B C 0.09620385985325813
# B D 0.09624095396451579
# B E 0.0961997538458332
# C D 0.09620414697925943
# C E 0.096219970993535
# D E 0.09640377624463167

# %%
plot_splits({f: dhs_locs[dhs_incountry_folds[f]['test']] for f in FOLDS},
            title='DHS in-country folds')

# %% [markdown]
# Read remove regions from geojson:

# %%
with open('remove_regions2_benno.json') as f:
    remove_regions_gj = json.load(f)

remove_regions = []
for region in remove_regions_gj['features']:
  remove_regions.append(Polygon(region['geometry']['coordinates'][0]))

# %%
def in_polys(point, polys):
  for poly in polys:
    if point.within(poly):
      return True
  return False

dhs_df['geomtery'] = dhs_df.apply(lambda row: Point(row['lon'], row['lat']), axis=1)
new_dhs_df = dhs_df[~(dhs_df['geomtery'].apply(lambda p: in_polys(p, remove_regions)))]

# %%
new_dhs_locs = new_dhs_df[['lat', 'lon']].values

new_dhs_incountry_test_folds = create_folds(
    locs=new_dhs_locs,
    min_dist=MIN_DIST,
    fold_names=FOLDS,
    plot_largest_clusters=5)

verify_folds(
    folds=new_dhs_incountry_test_folds,
    locs=new_dhs_locs,
    min_dist=MIN_DIST,
    max_index=len(new_dhs_locs))

new_dhs_incountry_folds = create_split_folds(
    test_folds=new_dhs_incountry_test_folds,
    fold_names=FOLDS)
# Out:
# num clusters: 4067
# num outliers: 6653
# max cluster size (excl. outliers): 2001
# Size of each fold
# {'A': 11349, 'B': 11348, 'C': 11348, 'D': 11348, 'E': 11348}
# Minimum distance between each pair of folds
# A B 0.09632209535200928
# A C 0.0961997538458332
# A D 0.096219970993535
# A E 0.09621279791609637
# B C 0.09624439466781931
# B D 0.09630498268521327
# B E 0.09622395168043944
# C D 0.09620414697925943
# C E 0.09623214395617946
# D E 0.09625651169532883

# %%
plot_splits({f: new_dhs_locs[new_dhs_incountry_folds[f]['test']] for f in FOLDS},
            title='Cross validation folds for supervised training set')
plt.savefig('cv_folds.png', bbox_inches='tight')

# %%
print(f'Percentage removed: {100 * ((dhs_df.shape[0] - new_dhs_df.shape[0])/dhs_df.shape[0])}%')
# Out:
# Percentage removed: 0.7937756796922808%

# %%
save_folds(
    folds_path='new_dhs_incountry_folds.pkl',
    folds=new_dhs_incountry_folds,
    check_exists=True)
